# %% [markdown]
# # 基于CNN模型的物体识别

# %% [markdown]
# ## 0.先完成理论部分即可

# %% [markdown]
# ## 1.复习上课内容以及复现课程代码

# %% [markdown]
# 在本部分，你需要复习上课内容和课程代码后，自己复现课程代码。

# %% [markdown]
# ## 2.回答以下理论题目?

# %% [markdown]
# ### 2.1. Suppose your input is a 100 by 100 gray image, and you use a convolutional layer with 50 filters that are each 5x5. How many parameters does this hidden layer have (including the bias parameters)?
#
# #### （100 - 5 + 1）X（100 - 5 + 1）X 50

# %% [markdown]
# ### 2.2. What are "local invariant" and "parameter sharing" ?
#
# - **因为图片的底层特征是与特征在图片中的位置无关的，所以采用local invariant以及parameter sharing可以减少参数数量，使运算变得简洁、高效，能够在超大规模数据集上运算**

# %% [markdown]
# ### 2.3. Why we use batch normalization ?
# - 批处理规范化（也称为批处理规范）是一种用于提高人工神经网络的速度，性能和稳定性的技术。
#
#
# - **Batch Normalization是在一种巧妙且粗暴的方法来削弱bad initialization的影响，其基本思想是：If you want it,just make it!我们想的是在非线性activation之前，输出值应该有比较好的分布（例如高斯分布），以便于back propagation时计算gradient，更新weight。**

# %% [markdown]
# ### 2.4. What problem does dropout try to solve ?
# - **费时，容易过拟合**
#
#
# 因为dropout它强迫一个神经单元，和随机挑选出来的其他神经单元共同工作，达到好的效果。消除减弱了神经元节点间的联合适应性，增强了泛化能力。

# %% [markdown]
# ## 3. 实践题

# %% [markdown]
# ### 3.1 In the first session of the practical part, you will implement an image classification model using any deep learning libraries that you are familiar with,  which means, except for tensorflow and keras, you can also use pytorch/caffe/... .  The dataset used in this session is the cifar10 which contains 50000 color (RGB) images, each with size 32x32x3.  All 50000 images are classified into ten categories.

# %%
import torch 
import torchvision
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim 
import torchvision.transforms as transforms
import torch.nn.functional as F

# 准备数据集并预处理
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),  #先四周填充0，在把图像随机裁剪成32*32
    transforms.RandomHorizontalFlip(),  #图像一半的概率翻转，一半的概率不翻转
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)), #R,G,B每层的归一化用到的均值和方差
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# 读取数据集
train_dataset = torchvision.datasets.CIFAR10(
      root = './',
      train = True,
      transform = transform_train,
      download = True)

test_dataset = torchvision.datasets.CIFAR10(
     root = './',
     train = False,
     transform = transform_test,
     download = True
 )

class ResidualBlock(nn.Module):
    def __init__(self, inchannel, outchannel, stride=1):
        super(ResidualBlock, self).__init__()
        self.left = nn.Sequential(
            nn.Conv2d(inchannel, outchannel, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(outchannel),
            nn.ReLU(inplace=True),
            nn.Conv2d(outchannel, outchannel, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(outchannel)
        )
        self.shortcut = nn.Sequential()
        if stride != 1 or inchannel != outchannel:
            self.shortcut = nn.Sequential(
                nn.Conv2d(inchannel, outchannel, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(outchannel)
            )

    def forward(self, x):
        out = self.left(x)
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ResNet(nn.Module):
    def __init__(self, ResidualBlock, num_classes=10):
        super(ResNet, self).__init__()
        self.inchannel = 64
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
        )
        self.layer1 = self.make_layer(ResidualBlock, 64,  2, stride=1)
        self.layer2 = self.make_layer(ResidualBlock, 128, 2, stride=2)
        self.layer3 = self.make_layer(ResidualBlock, 256, 2, stride=2)
        self.layer4 = self.make_layer(ResidualBlock, 512, 2, stride=2)
        self.fc = nn.Linear(512, num_classes)

    def make_layer(self, block, channels, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)   #strides=[1,1]
        layers = []
        for stride in strides:
            layers.append(block(self.inchannel, channels, stride))
            self.inchannel = channels
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.conv1(x)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out
    
def ResNet18():
    return ResNet(ResidualBlock)
net =ResNet18()
# print(net)
# 超参数设置
learn_rate = 0.0001
num_epoches = 180

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(),lr = learn_rate,betas = (0.9,0.99),weight_decay=5e-4)
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
# device = torch.device('cpu')

# 图片分批次送入内存（32张图片,batch_size），进行计算。
train_dataloader = DataLoader(dataset=train_dataset,batch_size=32,shuffle=True,num_workers=2)
test_dataloader = DataLoader(dataset=test_dataset)

# 训练阶段
net.to(device)

net.train()
for epoch in range(num_epoches):
    print(f'epoch:{epoch + 1}')
    for idx,(img,label) in enumerate(train_dataloader):
        images = img.to(device)
        labels = label.to(device)
        output = net(images)
        loss = criterion(output,labels)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        if idx % 100 == 0:
            print(f"| Step={idx//100}，current loss = {loss.item()}")

        
# 测试阶段
net.to(device)
net.eval()
total,correct = 0,0
for img,label in test_dataloader:
    images = img.to(device)
    labels = label.to(device)
    output = net(images)
    _,idx = torch.max(output.data,1)
    total += labels.size(0)
    correct += (idx == labels).sum()
    
print(f'accuracy:{100.*correct/total}')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# epoch:1
# | Step=0，current loss = 2.460303544998169
# | Step=1，current loss = 1.6955255270004272
# | Step=2，current loss = 1.6867762804031372
# | Step=3，current loss = 1.5862367153167725
# | Step=4，current loss = 1.4904260635375977
# | Step=5，current loss = 1.2605403661727905
# | Step=6，current loss = 1.08897066116333
# | Step=7，current loss = 1.5863913297653198
# | Step=8，current loss = 1.1882991790771484
# | Step=9，current loss = 1.0314640998840332
# | Step=10，current loss = 1.1954221725463867
# | Step=11，current loss = 1.1715610027313232
# | Step=12，current loss = 1.1835170984268188
# | Step=13，current loss = 0.9911937713623047
# | Step=14，current loss = 1.012398362159729
# | Step=15，current loss = 1.2501946687698364
# epoch:2
# | Step=0，current loss = 0.8314551115036011
# | Step=1，current loss = 0.6235232353210449
# | Step=2，current loss = 0.9312174320220947
# | Step=3，current loss = 0.9073468446731567
# | Step=4，current loss = 1.0458409786224365
# | Step=5，current loss = 0.7932109832763672
# | Step=6，current loss = 1.2277718782424927
# | Step=7，current loss = 1.0246604681015015
# | Step=8，current loss = 0.947528600692749
# | Step=9，current loss = 0.9852444529533386
# | Step=10，current loss = 0.7771925330162048
# | Step=11，current loss = 1.0492756366729736
# | Step=12，current loss = 0.5433859825134277
# | Step=13，current loss = 0.5482404232025146
# | Step=14，current loss = 0.4747964143753052
# | Step=15，current loss = 0.7865321636199951
# epoch:3
# | Step=0，current loss = 0.8905930519104004
# | Step=1，current loss = 0.6399474143981934
# | Step=2，current loss = 0.48287636041641235
# | Step=3，current loss = 0.6142841577529907
# | Step=4，current loss = 0.6229153871536255
# | Step=5，current loss = 0.5264495611190796
# | Step=6，current loss = 0.644052267074585
# | Step=7，current loss = 0.6399749517440796
# | Step=8，current loss = 0.4204792380332947
# | Step=9，current loss = 0.5785133242607117
# | Step=10，current loss = 0.9273539781570435
# | Step=11，current loss = 0.6872231960296631
# | Step=12，current loss = 0.6398240923881531
# | Step=13，current loss = 0.4642981290817261
# | Step=14，current loss = 0.7319464683532715
# | Step=15，current loss = 0.9504609107971191
# epoch:4
# | Step=0，current loss = 0.47249191999435425
# | Step=1，current loss = 0.5637374520301819
# | Step=2，current loss = 0.36276939511299133
# | Step=3，current loss = 0.4295971989631653
# | Step=4，current loss = 0.5270473957061768
# | Step=5，current loss = 0.5271243453025818
# | Step=6，current loss = 0.6948114633560181
# | Step=7，current loss = 0.4964092969894409
# | Step=8，current loss = 0.775820255279541
# | Step=9，current loss = 0.41227227449417114
# | Step=10，current loss = 0.5200737118721008
# | Step=11，current loss = 0.45180246233940125
# | Step=12，current loss = 0.4040810167789459
# | Step=13，current loss = 0.4483253061771393
# | Step=14，current loss = 0.6920053958892822
# | Step=15，current loss = 0.6314390897750854
# epoch:5
# | Step=0，current loss = 0.388896107673645
# | Step=1，current loss = 0.5510485172271729
# | Step=2，current loss = 0.460055410861969
# | Step=3，current loss = 0.6874958872795105
# | Step=4，current loss = 0.6491376161575317
# | Step=5，current loss = 0.442890465259552
# | Step=6，current loss = 0.46282288432121277
# | Step=7，current loss = 0.5468895435333252
# | Step=8，current loss = 0.4407758116722107
# | Step=9，current loss = 0.5043657422065735
# | Step=10，current loss = 0.8032359480857849
# | Step=11，current loss = 0.9201309084892273
# | Step=12，current loss = 0.49255818128585815
# | Step=13，current loss = 0.2581402659416199
# | Step=14，current loss = 0.5249783992767334
# | Step=15，current loss = 0.531579852104187
# epoch:6
# | Step=0，current loss = 0.26069632172584534
# | Step=1，current loss = 0.27540653944015503
# | Step=2，current loss = 0.40170320868492126
# | Step=3，current loss = 0.5279169082641602
# | Step=4，current loss = 0.38340890407562256
# | Step=5，current loss = 0.5139018297195435
# | Step=6，current loss = 0.21529698371887207
# | Step=7，current loss = 0.2738020420074463
# | Step=8，current loss = 0.51730877161026
# | Step=9，current loss = 0.5596246123313904
# | Step=10，current loss = 0.544181227684021
# | Step=11，current loss = 0.29244908690452576
# | Step=12，current loss = 0.49721288681030273
# | Step=13，current loss = 0.4006054401397705
# | Step=14，current loss = 0.36153721809387207
# | Step=15，current loss = 0.6627739071846008
# epoch:7
# | Step=0，current loss = 0.41389599442481995
# | Step=1，current loss = 0.3355407118797302
# | Step=2，current loss = 0.4624844789505005
# | Step=3，current loss = 0.4943125247955322
# | Step=4，current loss = 0.6862000823020935
# | Step=5，current loss = 0.1447843313217163
# | Step=6，current loss = 0.4448900818824768
# | Step=7，current loss = 0.5053864121437073
# | Step=8，current loss = 0.5264009833335876
# | Step=9，current loss = 0.6655421257019043
# | Step=10，current loss = 0.4075000286102295
# | Step=11，current loss = 0.3819462060928345
# | Step=12，current loss = 0.5569428205490112
# | Step=13，current loss = 0.6420190930366516
# | Step=14，current loss = 0.42543143033981323
# | Step=15，current loss = 0.7233697772026062
# epoch:8
# | Step=0，current loss = 0.4994068741798401
# | Step=1，current loss = 0.2951297163963318
# | Step=2，current loss = 0.3540382385253906
# | Step=3，current loss = 0.37163636088371277
# | Step=4，current loss = 0.2870902717113495
# | Step=5，current loss = 0.31657397747039795
# | Step=6，current loss = 0.4446057677268982
# | Step=7，current loss = 0.42499423027038574
# | Step=8，current loss = 0.13517658412456512
# | Step=9，current loss = 0.4223244786262512
# | Step=10，current loss = 0.24417567253112793
# | Step=11，current loss = 0.5006014704704285
# | Step=12，current loss = 0.3130996823310852
# | Step=13，current loss = 0.529149055480957
# | Step=14，current loss = 0.33150148391723633
# | Step=15，current loss = 0.2620578110218048
# epoch:9
# | Step=0，current loss = 0.4102967083454132
# | Step=1，current loss = 0.3631319999694824
# | Step=2，current loss = 0.3462628722190857
# | Step=3，current loss = 0.641032874584198
# | Step=4，current loss = 0.34655559062957764
# | Step=5，current loss = 0.6247612833976746
# | Step=6，current loss = 0.41905438899993896
# | Step=7，current loss = 0.6970837116241455
# | Step=8，current loss = 0.12848420441150665
# | Step=9，current loss = 0.6403826475143433
# | Step=10，current loss = 0.49910926818847656
# | Step=11，current loss = 0.30330562591552734
# | Step=12，current loss = 0.27510613203048706
# | Step=13，current loss = 0.3985343873500824
# | Step=14，current loss = 0.21011146903038025
# | Step=15，current loss = 0.2795790731906891
# epoch:10
# | Step=0，current loss = 0.42998194694519043
# | Step=1，current loss = 0.5517508387565613
# | Step=2，current loss = 0.5810243487358093
# | Step=3，current loss = 0.13335180282592773
# | Step=4，current loss = 0.2765010595321655
# | Step=5，current loss = 0.5937998294830322
# | Step=6，current loss = 0.13405895233154297
# | Step=7，current loss = 0.8995628356933594
# | Step=8，current loss = 0.6484724283218384
# | Step=9，current loss = 0.48517492413520813
# | Step=10，current loss = 0.4071357846260071
# | Step=11，current loss = 0.6093872785568237
# | Step=12，current loss = 0.2755671441555023
# | Step=13，current loss = 0.4102550148963928
# | Step=14，current loss = 0.1552971452474594
# | Step=15，current loss = 0.2065502107143402
# epoch:11
# | Step=0，current loss = 0.2378336787223816
# | Step=1，current loss = 0.4643785357475281
# | Step=2，current loss = 0.40182608366012573
# | Step=3，current loss = 0.38223928213119507
# | Step=4，current loss = 0.22430381178855896
# | Step=5，current loss = 0.36470845341682434
# | Step=6，current loss = 0.303330659866333
# | Step=7，current loss = 0.3841114640235901
# | Step=8，current loss = 0.31910574436187744
# | Step=9，current loss = 0.6859127879142761
# | Step=10，current loss = 0.28024595975875854
# | Step=11，current loss = 0.36760276556015015
# | Step=12，current loss = 0.18058346211910248
# | Step=13，current loss = 0.5075739622116089
# | Step=14，current loss = 0.24875310063362122
# | Step=15，current loss = 0.4646587371826172
# epoch:12
# | Step=0，current loss = 0.23118004202842712
# | Step=1，current loss = 0.30879348516464233
# | Step=2，current loss = 0.26085948944091797
# | Step=3，current loss = 0.3358916640281677
# | Step=4，current loss = 0.23643839359283447
# | Step=5，current loss = 0.22412192821502686
# | Step=6，current loss = 0.2956855893135071
# | Step=7，current loss = 0.2808029353618622
# | Step=8，current loss = 0.23949021100997925
# | Step=9，current loss = 0.329790860414505
# | Step=10，current loss = 0.3564782738685608
# | Step=11，current loss = 0.25382739305496216
# | Step=12，current loss = 0.2052624374628067
# | Step=13，current loss = 0.3437477946281433
# | Step=14，current loss = 0.4146844148635864
# | Step=15，current loss = 0.17597870528697968
# epoch:13
# | Step=0，current loss = 0.04752608388662338
# | Step=1，current loss = 0.259948194026947
# | Step=2，current loss = 0.16827625036239624
# | Step=3，current loss = 0.258475661277771
# | Step=4，current loss = 0.08854600787162781
# | Step=5，current loss = 0.4119717478752136
# | Step=6，current loss = 0.3106803894042969
# | Step=7，current loss = 0.1810545176267624
# | Step=8，current loss = 0.2685573101043701
# | Step=9，current loss = 0.46152082085609436
# | Step=10，current loss = 0.1773146390914917
# | Step=11，current loss = 0.2412160485982895
# | Step=12，current loss = 0.27131226658821106
# | Step=13，current loss = 0.12242382764816284
# | Step=14，current loss = 0.2227548062801361
# | Step=15，current loss = 0.22751671075820923
# epoch:14
# | Step=0，current loss = 0.1821993738412857
# | Step=1，current loss = 0.3977610468864441
# | Step=2，current loss = 0.16776397824287415
# | Step=3，current loss = 0.23711517453193665
# | Step=4，current loss = 0.5489120483398438
# | Step=5，current loss = 0.455514132976532
# | Step=6，current loss = 0.15511460602283478
# | Step=7，current loss = 0.4291170835494995
# | Step=8，current loss = 0.19025559723377228
# | Step=9，current loss = 0.23346100747585297
# | Step=10，current loss = 0.1745498776435852
# | Step=11，current loss = 0.2908106744289398
# | Step=12，current loss = 0.1707388460636139
# | Step=13，current loss = 0.1549789011478424
# | Step=14，current loss = 0.30223891139030457
# | Step=15，current loss = 0.491981565952301
# epoch:15
# | Step=0，current loss = 0.34796667098999023
# | Step=1，current loss = 0.18053314089775085
# | Step=2，current loss = 0.4388096034526825
# | Step=3，current loss = 0.13815994560718536
# | Step=4，current loss = 0.4824206829071045
# | Step=5，current loss = 0.4526461958885193
# | Step=6，current loss = 0.3235437870025635
# | Step=7，current loss = 0.4136695861816406
# | Step=8，current loss = 0.39332085847854614
# | Step=9，current loss = 0.09268875420093536
# | Step=10，current loss = 0.16438162326812744
# | Step=11，current loss = 0.42839422821998596
# | Step=12，current loss = 0.19103001058101654
# | Step=13，current loss = 0.07544416189193726
# | Step=14，current loss = 0.1847405880689621
# | Step=15，current loss = 0.2454037219285965
# epoch:16
# | Step=0，current loss = 0.2763628363609314
# | Step=1，current loss = 0.236988365650177
# | Step=2，current loss = 0.08760923147201538
# | Step=3，current loss = 0.08645214140415192
# | Step=4，current loss = 0.34369003772735596
# | Step=5，current loss = 0.28139030933380127
# | Step=6，current loss = 0.07861732691526413
# | Step=7，current loss = 0.14796744287014008
# | Step=8，current loss = 0.13954971730709076
# | Step=9，current loss = 0.26062992215156555
# | Step=10，current loss = 0.05491670221090317
# | Step=11，current loss = 0.411700576543808
# | Step=12，current loss = 0.3235124349594116
# | Step=13，current loss = 0.07023727893829346
# | Step=14，current loss = 0.2994481325149536
# | Step=15，current loss = 0.5324030518531799
# epoch:17
# | Step=0，current loss = 0.22949202358722687
# | Step=1，current loss = 0.30551257729530334
# | Step=2，current loss = 0.24212917685508728
# | Step=3，current loss = 0.21823841333389282
# | Step=4，current loss = 0.4351470470428467
# | Step=5，current loss = 0.24455420672893524
# | Step=6，current loss = 0.05761142820119858
# | Step=7，current loss = 0.4401487112045288
# | Step=8，current loss = 0.1321679949760437
# | Step=9，current loss = 0.3389996886253357
# | Step=10，current loss = 0.4270402193069458
# | Step=11，current loss = 0.2721793055534363
# | Step=12，current loss = 0.27631381154060364
# | Step=13，current loss = 0.26789161562919617
# | Step=14，current loss = 0.28043031692504883
# | Step=15，current loss = 0.3507159948348999
# epoch:18
# | Step=0，current loss = 0.2946532964706421
# | Step=1，current loss = 0.34117719531059265
# | Step=2，current loss = 0.3773653209209442
# | Step=3，current loss = 0.1500331163406372
# | Step=4，current loss = 0.19531066715717316
# | Step=5，current loss = 0.36245572566986084
# | Step=6，current loss = 0.12716567516326904
# | Step=7，current loss = 0.16079066693782806
# | Step=8，current loss = 0.10165451467037201
# | Step=9，current loss = 0.12916943430900574
# | Step=10，current loss = 0.4097963869571686
# | Step=11，current loss = 0.0672377347946167
# | Step=12，current loss = 0.29268771409988403
# | Step=13，current loss = 0.5822789669036865
# | Step=14，current loss = 0.7272887229919434
# | Step=15，current loss = 0.32816413044929504
# epoch:19
# | Step=0，current loss = 0.16874580085277557
# | Step=1，current loss = 0.08129595220088959
# | Step=2，current loss = 0.2156042754650116
# | Step=3，current loss = 0.18216440081596375
# | Step=4，current loss = 0.32112982869148254
# | Step=5，current loss = 0.26236453652381897
# | Step=6，current loss = 0.13078908622264862
# | Step=7，current loss = 0.305126428604126
# | Step=8，current loss = 0.18194198608398438
# | Step=9，current loss = 0.5563428997993469
# | Step=10，current loss = 0.18127219378948212
# | Step=11，current loss = 0.1913529634475708
# | Step=12，current loss = 0.2412111908197403
# | Step=13，current loss = 0.4797128438949585
# | Step=14，current loss = 0.14558514952659607
# | Step=15，current loss = 0.24455057084560394
# epoch:20
# | Step=0，current loss = 0.22879540920257568
# | Step=1，current loss = 0.08000673353672028
# | Step=2，current loss = 0.21287958323955536
# | Step=3，current loss = 0.2122102975845337
# | Step=4，current loss = 0.23585553467273712
# | Step=5，current loss = 0.08562483638525009
# | Step=6，current loss = 0.25387516617774963
# | Step=7，current loss = 0.06299298256635666
# | Step=8，current loss = 0.0944102331995964
# | Step=9，current loss = 0.22833742201328278
# | Step=10，current loss = 0.31947100162506104
# | Step=11，current loss = 0.2582589089870453
# | Step=12，current loss = 0.1324845552444458
# | Step=13，current loss = 0.16227298974990845
# | Step=14，current loss = 0.10034549981355667
# | Step=15，current loss = 0.16582006216049194
# epoch:21
# | Step=0，current loss = 0.24903042614459991
# | Step=1，current loss = 0.32446762919425964
# | Step=2，current loss = 0.3982681930065155
# | Step=3，current loss = 0.17028942704200745
# | Step=4，current loss = 0.34681615233421326
# | Step=5，current loss = 0.11404623091220856
# | Step=6，current loss = 0.2534678280353546
# | Step=7，current loss = 0.1376054733991623
# | Step=8，current loss = 0.22023698687553406
# | Step=9，current loss = 0.14068935811519623
# | Step=10，current loss = 0.23162806034088135
# | Step=11，current loss = 0.2352539300918579
# | Step=12，current loss = 0.11054997891187668
# | Step=13，current loss = 0.13205523788928986
# | Step=14，current loss = 0.17238780856132507
# | Step=15，current loss = 0.11943049728870392
# epoch:22
# | Step=0，current loss = 0.09498538076877594
# | Step=1，current loss = 0.19512224197387695
# | Step=2，current loss = 0.29362693428993225
# | Step=3，current loss = 0.19362737238407135
# | Step=4，current loss = 0.23034697771072388
# | Step=5，current loss = 0.20717141032218933
# | Step=6，current loss = 0.33984503149986267
# | Step=7，current loss = 0.18856596946716309
# | Step=8，current loss = 0.09730809181928635
# | Step=9，current loss = 0.08245658129453659
# | Step=10，current loss = 0.4212127923965454
# | Step=11，current loss = 0.09803679585456848
# | Step=12，current loss = 0.299320787191391
# | Step=13，current loss = 0.20169682800769806
# | Step=14，current loss = 0.24156832695007324
# | Step=15，current loss = 0.5190384387969971
# epoch:23
# | Step=0，current loss = 0.23158963024616241
# | Step=1，current loss = 0.12739400565624237
# | Step=2，current loss = 0.17430685460567474
# | Step=3，current loss = 0.3435589075088501
# | Step=4，current loss = 0.08143564313650131
# | Step=5，current loss = 0.34468430280685425
# | Step=6，current loss = 0.19412392377853394
# | Step=7，current loss = 0.1618053913116455
# | Step=8，current loss = 0.28639644384384155
# | Step=9，current loss = 0.0574924536049366
# | Step=10，current loss = 0.050244253128767014
# | Step=11，current loss = 0.1549062430858612
# | Step=12，current loss = 0.1104574054479599
# | Step=13，current loss = 0.19381515681743622
# | Step=14，current loss = 0.17494896054267883
# | Step=15，current loss = 0.3505746126174927
# epoch:24
# | Step=0，current loss = 0.13667812943458557
# | Step=1，current loss = 0.16014821827411652
# | Step=2，current loss = 0.08022626489400864
# | Step=3，current loss = 0.2501789331436157
# | Step=4，current loss = 0.03076338768005371
# | Step=5，current loss = 0.27391594648361206
# | Step=6，current loss = 0.08528610318899155
# | Step=7，current loss = 0.20071491599082947
# | Step=8，current loss = 0.07842124253511429
# | Step=9，current loss = 0.03678638115525246
# | Step=10，current loss = 0.15333017706871033
# | Step=11，current loss = 0.06483416259288788
# | Step=12，current loss = 0.11829102039337158
# | Step=13，current loss = 0.19749553501605988
# | Step=14，current loss = 0.40693148970603943
# | Step=15，current loss = 0.20321735739707947
# epoch:25
# | Step=0，current loss = 0.23341970145702362
# | Step=1，current loss = 0.052742987871170044
# | Step=2，current loss = 0.25074535608291626
# | Step=3，current loss = 0.2778412699699402
# | Step=4，current loss = 0.20053476095199585
# | Step=5，current loss = 0.21651160717010498
# | Step=6，current loss = 0.10961746424436569
# | Step=7，current loss = 0.14779870212078094
# | Step=8，current loss = 0.06779078394174576
# | Step=9，current loss = 0.14508336782455444
# | Step=10，current loss = 0.036415595561265945
# | Step=11，current loss = 0.1070692166686058
# | Step=12，current loss = 0.25959765911102295
# | Step=13，current loss = 0.054837554693222046
# | Step=14，current loss = 0.09149440377950668
# | Step=15，current loss = 0.17791138589382172
# epoch:26
# | Step=0，current loss = 0.13772447407245636
# | Step=1，current loss = 0.15180808305740356
# | Step=2，current loss = 0.04465700685977936
# | Step=3，current loss = 0.27216529846191406
# | Step=4，current loss = 0.2664218544960022
# | Step=5，current loss = 0.2778022289276123
# | Step=6，current loss = 0.12138538062572479
# | Step=7，current loss = 0.13513076305389404
# | Step=8，current loss = 0.3163701295852661
# | Step=9，current loss = 0.27034792304039
# | Step=10，current loss = 0.10198216140270233
# | Step=11，current loss = 0.16002926230430603
# | Step=12，current loss = 0.1633608639240265
# | Step=13，current loss = 0.010501742362976074
# | Step=14，current loss = 0.17672955989837646
# | Step=15，current loss = 0.3971249461174011
# epoch:27
# | Step=0，current loss = 0.10470286756753922
# | Step=1，current loss = 0.07443398237228394
# | Step=2，current loss = 0.051788367331027985
# | Step=3，current loss = 0.09065234661102295
# | Step=4，current loss = 0.044585395604372025
# | Step=5，current loss = 0.11305373162031174
# | Step=6，current loss = 0.15392524003982544
# | Step=7，current loss = 0.3337394893169403
# | Step=8，current loss = 0.09368380904197693
# | Step=9，current loss = 0.12155710905790329
# | Step=10，current loss = 0.08622808009386063
# | Step=11，current loss = 0.37831437587738037
# | Step=12，current loss = 0.057044390588998795
# | Step=13，current loss = 0.1887345314025879
# | Step=14，current loss = 0.11040981858968735
# | Step=15，current loss = 0.12361939996480942
# epoch:28
# | Step=0，current loss = 0.18657273054122925
# | Step=1，current loss = 0.18491125106811523
# | Step=2，current loss = 0.06983868032693863
# | Step=3，current loss = 0.2539382576942444
# | Step=4，current loss = 0.030683640390634537
# | Step=5，current loss = 0.18537300825119019
# | Step=6，current loss = 0.06286599487066269
# | Step=7，current loss = 0.09148655831813812
# | Step=8，current loss = 0.1155746728181839
# | Step=9，current loss = 0.2735074758529663
# | Step=10，current loss = 0.01673126220703125
# | Step=11，current loss = 0.34547412395477295
# | Step=12，current loss = 0.10486266016960144
# | Step=13，current loss = 0.2926827073097229
# | Step=14，current loss = 0.04853537678718567
# | Step=15，current loss = 0.17812396585941315
# epoch:29
# | Step=0，current loss = 0.2227897197008133
# | Step=1，current loss = 0.10948910564184189
# | Step=2，current loss = 0.3840612471103668
# | Step=3，current loss = 0.07523353397846222
# | Step=4，current loss = 0.08777576684951782
# | Step=5，current loss = 0.48273319005966187
# | Step=6，current loss = 0.1749396026134491
# | Step=7，current loss = 0.11014364659786224
# | Step=8，current loss = 0.24008652567863464
# | Step=9，current loss = 0.1173352524638176
# | Step=10，current loss = 0.12619052827358246
# | Step=11，current loss = 0.17448361217975616
# | Step=12，current loss = 0.08930356055498123
# | Step=13，current loss = 0.036866217851638794
# | Step=14，current loss = 0.412193238735199
# | Step=15，current loss = 0.1409890055656433
# epoch:30
# | Step=0，current loss = 0.20866768062114716
# | Step=1，current loss = 0.042469583451747894
# | Step=2，current loss = 0.37620699405670166
# | Step=3，current loss = 0.2416987419128418
# | Step=4，current loss = 0.2093128114938736
# | Step=5，current loss = 0.2747052013874054
# | Step=6，current loss = 0.18465128540992737
# | Step=7，current loss = 0.1603848785161972
# | Step=8，current loss = 0.03427460417151451
# | Step=9，current loss = 0.28367510437965393
# | Step=10，current loss = 0.2803348898887634
# | Step=11，current loss = 0.17866677045822144
# | Step=12，current loss = 0.16849656403064728
# | Step=13，current loss = 0.11216506361961365
# | Step=14，current loss = 0.25136661529541016
# | Step=15，current loss = 0.2673304080963135
# epoch:31
# | Step=0，current loss = 0.34336286783218384
# | Step=1，current loss = 0.17383599281311035
# | Step=2，current loss = 0.11706120520830154
# | Step=3，current loss = 0.11582258343696594
# | Step=4，current loss = 0.22888484597206116
# | Step=5，current loss = 0.11110152304172516
# | Step=6，current loss = 0.053341303020715714
# | Step=7，current loss = 0.11981359124183655
# | Step=8，current loss = 0.12083457410335541
# | Step=9，current loss = 0.07298996299505234
# | Step=10，current loss = 0.19677482545375824
# | Step=11，current loss = 0.1815536916255951
# | Step=12，current loss = 0.19266632199287415
# | Step=13，current loss = 0.14226312935352325
# | Step=14，current loss = 0.1462322473526001
# | Step=15，current loss = 0.38808390498161316
# epoch:32
# | Step=0，current loss = 0.14772136509418488
# | Step=1，current loss = 0.11647720634937286
# | Step=2，current loss = 0.20669931173324585
# | Step=3，current loss = 0.3102339208126068
# | Step=4，current loss = 0.30980920791625977
# | Step=5，current loss = 0.3078116774559021
# | Step=6，current loss = 0.07554146647453308
# | Step=7，current loss = 0.0381411574780941
# | Step=8，current loss = 0.14562176167964935
# | Step=9，current loss = 0.03755250200629234
# | Step=10，current loss = 0.20329439640045166
# | Step=11，current loss = 0.05445113778114319
# | Step=12，current loss = 0.3565370440483093
# | Step=13，current loss = 0.10919735580682755
# | Step=14，current loss = 0.19259679317474365
# | Step=15，current loss = 0.1316295564174652
# epoch:33
# | Step=0，current loss = 0.26163727045059204
# | Step=1，current loss = 0.09091698378324509
# | Step=2，current loss = 0.12565776705741882
# | Step=3，current loss = 0.08310646563768387
# | Step=4，current loss = 0.17649251222610474
# | Step=5，current loss = 0.24118927121162415
# | Step=6，current loss = 0.1151825487613678
# | Step=7，current loss = 0.15149596333503723
# | Step=8，current loss = 0.08842932432889938
# | Step=9，current loss = 0.017459571361541748
# | Step=10，current loss = 0.13134048879146576
# | Step=11，current loss = 0.012949831783771515
# | Step=12，current loss = 0.13247479498386383
# | Step=13，current loss = 0.17862169444561005
# | Step=14，current loss = 0.040815796703100204
# | Step=15，current loss = 0.3962365686893463
# epoch:34
# | Step=0，current loss = 0.0874028354883194
# | Step=1，current loss = 0.24164292216300964
# | Step=2，current loss = 0.09127125889062881
# | Step=3，current loss = 0.08430057018995285
# | Step=4，current loss = 0.11285149306058884
# | Step=5，current loss = 0.06931471824645996
# | Step=6，current loss = 0.4195030927658081
# | Step=7，current loss = 0.1553698033094406
# | Step=8，current loss = 0.0760679841041565
# | Step=9，current loss = 0.040978386998176575
# | Step=10，current loss = 0.1140248030424118
# | Step=11，current loss = 0.12549547851085663
# | Step=12，current loss = 0.13519608974456787
# | Step=13，current loss = 0.0635598748922348
# | Step=14，current loss = 0.08719588071107864
# | Step=15，current loss = 0.1823587268590927
# epoch:35
# | Step=0，current loss = 0.041036467999219894
# | Step=1，current loss = 0.09317158907651901
# | Step=2，current loss = 0.27801913022994995
# | Step=3，current loss = 0.17060910165309906
# | Step=4，current loss = 0.1948780119419098
# | Step=5，current loss = 0.08850226551294327
# | Step=6，current loss = 0.04704180732369423
# | Step=7，current loss = 0.19737523794174194
# | Step=8，current loss = 0.4272768497467041
# | Step=9，current loss = 0.06866320222616196
# | Step=10，current loss = 0.1697271168231964
# | Step=11，current loss = 0.06307483464479446
# | Step=12，current loss = 0.04307926446199417
# | Step=13，current loss = 0.12887610495090485
# | Step=14，current loss = 0.17223306000232697
# | Step=15，current loss = 0.031868185847997665
# epoch:36
# | Step=0，current loss = 0.046342115849256516
# | Step=1，current loss = 0.12280341982841492
# | Step=2，current loss = 0.03357291966676712
# | Step=3，current loss = 0.07741671800613403
# | Step=4，current loss = 0.12086817622184753
# | Step=5，current loss = 0.16312940418720245
# | Step=6，current loss = 0.09600241482257843
# | Step=7，current loss = 0.2728841304779053
# | Step=8，current loss = 0.148878276348114
# | Step=9，current loss = 0.10690076649188995
# | Step=10，current loss = 0.13930131494998932
# | Step=11，current loss = 0.09716949611902237
# | Step=12，current loss = 0.07549797743558884
# | Step=13，current loss = 0.04258499667048454
# | Step=14，current loss = 0.10153400897979736
# | Step=15，current loss = 0.10911176353693008
# epoch:37
# | Step=0，current loss = 0.02856779843568802
# | Step=1，current loss = 0.13809938728809357
# | Step=2，current loss = 0.1266735941171646
# | Step=3，current loss = 0.1192651242017746
# | Step=4，current loss = 0.1606040894985199
# | Step=5，current loss = 0.07995903491973877
# | Step=6，current loss = 0.21659821271896362
# | Step=7，current loss = 0.06175971031188965
# | Step=8，current loss = 0.3114584982395172
# | Step=9，current loss = 0.26464390754699707
# | Step=10，current loss = 0.1350824534893036
# | Step=11，current loss = 0.05748104304075241
# | Step=12，current loss = 0.0789218619465828
# | Step=13，current loss = 0.29446643590927124
# | Step=14，current loss = 0.03739854693412781
# | Step=15，current loss = 0.08211573958396912
# epoch:38
# | Step=0，current loss = 0.09701370447874069
# | Step=1，current loss = 0.04852175712585449
# | Step=2，current loss = 0.16118597984313965
# | Step=3，current loss = 0.10767421871423721
# | Step=4，current loss = 0.28808295726776123
# | Step=5，current loss = 0.010709881782531738
# | Step=6，current loss = 0.27250540256500244
# | Step=7，current loss = 0.15069937705993652
# | Step=8，current loss = 0.33077457547187805
# | Step=9，current loss = 0.15274865925312042
# | Step=10，current loss = 0.08246190845966339
# | Step=11，current loss = 0.1902746707201004
# | Step=12，current loss = 0.039167776703834534
# | Step=13，current loss = 0.15076246857643127
# | Step=14，current loss = 0.17897440493106842
# | Step=15，current loss = 0.15670821070671082
# epoch:39
# | Step=0，current loss = 0.047486864030361176
# | Step=1，current loss = 0.09776508063077927
# | Step=2，current loss = 0.17510807514190674
# | Step=3，current loss = 0.24072742462158203
# | Step=4，current loss = 0.20844131708145142
# | Step=5，current loss = 0.3355708718299866
# | Step=6，current loss = 0.18179012835025787
# | Step=7，current loss = 0.04126399755477905
# | Step=8，current loss = 0.028445959091186523
# | Step=9，current loss = 0.017316393554210663
# | Step=10，current loss = 0.025842338800430298
# | Step=11，current loss = 0.10708725452423096
# | Step=12，current loss = 0.017450060695409775
# | Step=13，current loss = 0.09825360774993896
# | Step=14，current loss = 0.018919028341770172
# | Step=15，current loss = 0.11516646295785904
# epoch:40
# | Step=0，current loss = 0.19357800483703613
# | Step=1，current loss = 0.0925174131989479
# | Step=2，current loss = 0.048681873828172684
# | Step=3，current loss = 0.12876693904399872
# | Step=4，current loss = 0.22105325758457184
# | Step=5，current loss = 0.13871553540229797
# | Step=6，current loss = 0.0985567644238472
# | Step=7，current loss = 0.11760741472244263
# | Step=8，current loss = 0.0272110253572464
# | Step=9，current loss = 0.13651452958583832
# | Step=10，current loss = 0.10553392767906189
# | Step=11，current loss = 0.13913048803806305
# | Step=12，current loss = 0.036104463040828705
# | Step=13，current loss = 0.18398773670196533
# | Step=14，current loss = 0.14624595642089844
# | Step=15，current loss = 0.03984668850898743
# epoch:41
# | Step=0，current loss = 0.13136786222457886
# | Step=1，current loss = 0.09051570296287537
# | Step=2，current loss = 0.1132998839020729
# | Step=3，current loss = 0.12402549386024475
# | Step=4，current loss = 0.03115047886967659
# | Step=5，current loss = 0.06660745292901993
# | Step=6，current loss = 0.09578089416027069
# | Step=7，current loss = 0.14527511596679688
# | Step=8，current loss = 0.10183020681142807
# | Step=9，current loss = 0.3380897641181946
# | Step=10，current loss = 0.08651220053434372
# | Step=11，current loss = 0.09707440435886383
# | Step=12，current loss = 0.12154289335012436
# | Step=13，current loss = 0.05691095441579819
# | Step=14，current loss = 0.08607175946235657
# | Step=15，current loss = 0.22288645803928375
# epoch:42
# | Step=0，current loss = 0.08013373613357544
# | Step=1，current loss = 0.15615704655647278
# | Step=2，current loss = 0.08427426218986511
# | Step=3，current loss = 0.027140721678733826
# | Step=4，current loss = 0.1393412947654724
# | Step=5，current loss = 0.3506602644920349
# | Step=6，current loss = 0.16585583984851837
# | Step=7，current loss = 0.13775551319122314
# | Step=8，current loss = 0.09058024734258652
# | Step=9，current loss = 0.25470641255378723
# | Step=10，current loss = 0.1462816745042801
# | Step=11，current loss = 0.05425208434462547
# | Step=12，current loss = 0.05000459775328636
# | Step=13，current loss = 0.06515175104141235
# | Step=14，current loss = 0.07454840838909149
# | Step=15，current loss = 0.2551599442958832
# epoch:43
# | Step=0，current loss = 0.11258767545223236
# | Step=1，current loss = 0.08855051547288895
# | Step=2，current loss = 0.051723480224609375
# | Step=3，current loss = 0.23461216688156128
# | Step=4，current loss = 0.052657827734947205
# | Step=5，current loss = 0.07283520698547363
# | Step=6，current loss = 0.15840734541416168
# | Step=7，current loss = 0.09539187699556351
# | Step=8，current loss = 0.012593299150466919
# | Step=9，current loss = 0.03874920681118965
# | Step=10，current loss = 0.06510408222675323
# | Step=11，current loss = 0.33232468366622925
# | Step=12，current loss = 0.11082194745540619
# | Step=13，current loss = 0.14513975381851196
# | Step=14，current loss = 0.23262938857078552
# | Step=15，current loss = 0.03772374987602234
# epoch:44
# | Step=0，current loss = 0.03398226946592331
# | Step=1，current loss = 0.11952279508113861
# | Step=2，current loss = 0.03325490653514862
# | Step=3，current loss = 0.07097306102514267
# | Step=4，current loss = 0.1129397600889206
# | Step=5，current loss = 0.1136520728468895
# | Step=6，current loss = 0.25971853733062744
# | Step=7，current loss = 0.02816183678805828
# | Step=8，current loss = 0.15157048404216766
# | Step=9，current loss = 0.018872208893299103
# | Step=10，current loss = 0.09808133542537689
# | Step=11，current loss = 0.13628914952278137
# | Step=12，current loss = 0.02409350872039795
# | Step=13，current loss = 0.09005576372146606
# | Step=14，current loss = 0.19938980042934418
# | Step=15，current loss = 0.06576334685087204
# epoch:45
# | Step=0，current loss = 0.21654044091701508
# | Step=1，current loss = 0.16703301668167114
# | Step=2，current loss = 0.1029835194349289
# | Step=3，current loss = 0.07442495971918106
# | Step=4，current loss = 0.1061486154794693
# | Step=5，current loss = 0.06046219542622566
# | Step=6，current loss = 0.18166442215442657
# | Step=7，current loss = 0.30380094051361084
# | Step=8，current loss = 0.004508771002292633
# | Step=9，current loss = 0.08527694642543793
# | Step=10，current loss = 0.12091180682182312
# | Step=11，current loss = 0.14612555503845215
# | Step=12，current loss = 0.12431138753890991
# | Step=13，current loss = 0.27288511395454407
# | Step=14，current loss = 0.06801114976406097
# | Step=15，current loss = 0.11012648046016693
# epoch:46
# | Step=0，current loss = 0.18938036262989044
# | Step=1，current loss = 0.1881224662065506
# | Step=2，current loss = 0.06691918522119522
# | Step=3，current loss = 0.05145031586289406
# | Step=4，current loss = 0.03819139301776886
# | Step=5，current loss = 0.03408095985651016
# | Step=6，current loss = 0.23424607515335083
# | Step=7，current loss = 0.0330144502222538
# | Step=8，current loss = 0.08654534071683884
# | Step=9，current loss = 0.05024431273341179
# | Step=10，current loss = 0.16520482301712036
# | Step=11，current loss = 0.062015969306230545
# | Step=12，current loss = 0.008924566209316254
# | Step=13，current loss = 0.025275804102420807
# | Step=14，current loss = 0.15809616446495056
# | Step=15，current loss = 0.08298592269420624
# epoch:47
# | Step=0，current loss = 0.19994571805000305
# | Step=1，current loss = 0.08727023005485535
# | Step=2，current loss = 0.040564894676208496
# | Step=3，current loss = 0.03084459900856018
# | Step=4，current loss = 0.11997848004102707
# | Step=5，current loss = 0.09215458482503891
# | Step=6，current loss = 0.07012604176998138
# | Step=7，current loss = 0.022462941706180573
# | Step=8，current loss = 0.20485077798366547
# | Step=9，current loss = 0.07419390231370926
# | Step=10，current loss = 0.2126319855451584
# | Step=11，current loss = 0.24780488014221191
# | Step=12，current loss = 0.05119967460632324
# | Step=13，current loss = 0.12546704709529877
# | Step=14，current loss = 0.09830296784639359
# | Step=15，current loss = 0.16289909183979034
# epoch:48
# | Step=0，current loss = 0.1964302361011505
# | Step=1，current loss = 0.040781714022159576
# | Step=2，current loss = 0.02125752717256546
# | Step=3，current loss = 0.05223032087087631
# | Step=4，current loss = 0.1593700647354126
# | Step=5，current loss = 0.02272021770477295
# | Step=6，current loss = 0.11672182381153107
# | Step=7，current loss = 0.01566985994577408
# | Step=8，current loss = 0.25031930208206177
# | Step=9，current loss = 0.1679331511259079
# | Step=10，current loss = 0.0525226816534996
# | Step=11，current loss = 0.24135330319404602
# | Step=12，current loss = 0.17259621620178223
# | Step=13，current loss = 0.036174602806568146
# | Step=14，current loss = 0.018927358090877533
# | Step=15，current loss = 0.12221920490264893
# epoch:49
# | Step=0，current loss = 0.171002596616745
# | Step=1，current loss = 0.03686342388391495
# | Step=2，current loss = 0.03221640735864639
# | Step=3，current loss = 0.010112650692462921
# | Step=4，current loss = 0.01805504783987999
# | Step=5，current loss = 0.013920247554779053
# | Step=6，current loss = 0.027730613946914673
# | Step=7，current loss = 0.034362465143203735
# | Step=8，current loss = 0.038453131914138794
# | Step=9，current loss = 0.1109970286488533
# | Step=10，current loss = 0.10052793473005295
# | Step=11，current loss = 0.04356278479099274
# | Step=12，current loss = 0.09142957627773285
# | Step=13，current loss = 0.042714692652225494
# | Step=14，current loss = 0.016415245831012726
# | Step=15，current loss = 0.10270043462514877
# epoch:50
# | Step=0，current loss = 0.1759158819913864
# | Step=1，current loss = 0.10021484643220901
# | Step=2，current loss = 0.15502572059631348
# | Step=3，current loss = 0.0452980175614357
# | Step=4，current loss = 0.06320691108703613
# | Step=5，current loss = 0.2564869821071625
# | Step=6，current loss = 0.02220960706472397
# | Step=7，current loss = 0.06756886839866638
# | Step=8，current loss = 0.07299921661615372
# | Step=9，current loss = 0.021263957023620605
# | Step=10，current loss = 0.039222363382577896
# | Step=11，current loss = 0.11068595945835114
# | Step=12，current loss = 0.020514901727437973
# | Step=13，current loss = 0.0856499969959259
# | Step=14，current loss = 0.07207228243350983
# | Step=15，current loss = 0.005458466708660126
# epoch:51
# | Step=0，current loss = 0.08528193831443787
# | Step=1，current loss = 0.17936019599437714
# | Step=2，current loss = 0.0487605482339859
# | Step=3，current loss = 0.04190406948328018
# | Step=4，current loss = 0.030498284846544266
# | Step=5，current loss = 0.07230918109416962
# | Step=6，current loss = 0.08229757845401764
# | Step=7，current loss = 0.05001363903284073
# | Step=8，current loss = 0.06589508056640625
# | Step=9，current loss = 0.0822310820221901
# | Step=10，current loss = 0.023235760629177094
# | Step=11，current loss = 0.10036598891019821
# | Step=12，current loss = 0.10797134041786194
# | Step=13，current loss = 0.22514235973358154
# | Step=14，current loss = 0.05978436395525932
# | Step=15，current loss = 0.3541366457939148
# epoch:52
# | Step=0，current loss = 0.017118655145168304
# | Step=1，current loss = 0.1868131160736084
# | Step=2，current loss = 0.06336547434329987
# | Step=3，current loss = 0.16779252886772156
# | Step=4，current loss = 0.04682523384690285
# | Step=5，current loss = 0.0423729345202446
# | Step=6，current loss = 0.013827338814735413
# | Step=7，current loss = 0.14394937455654144
# | Step=8，current loss = 0.13895131647586823
# | Step=9，current loss = 0.18660101294517517
# | Step=10，current loss = 0.028182178735733032
# | Step=11，current loss = 0.021119438111782074
# | Step=12，current loss = 0.06368199735879898
# | Step=13，current loss = 0.11749330163002014
# | Step=14，current loss = 0.06287053227424622
# | Step=15，current loss = 0.09120708703994751
# epoch:53
# | Step=0，current loss = 0.0351334847509861
# | Step=1，current loss = 0.10010472685098648
# | Step=2，current loss = 0.1472664773464203
# | Step=3，current loss = 0.06098169833421707
# | Step=4，current loss = 0.0639738067984581
# | Step=5，current loss = 0.09060651063919067
# | Step=6，current loss = 0.15807780623435974
# | Step=7，current loss = 0.16439352929592133
# | Step=8，current loss = 0.37152522802352905
# | Step=9，current loss = 0.1965836137533188
# | Step=10，current loss = 0.04937489703297615
# | Step=11，current loss = 0.01653459668159485
# | Step=12，current loss = 0.3209981620311737
# | Step=13，current loss = 0.24778875708580017
# | Step=14，current loss = 0.13075397908687592
# | Step=15，current loss = 0.06578227877616882
# epoch:54
# | Step=0，current loss = 0.0250944122672081
# | Step=1，current loss = 0.15010373294353485
# | Step=2，current loss = 0.19488182663917542
# | Step=3，current loss = 0.0069310665130615234
# | Step=4，current loss = 0.13868583738803864
# | Step=5，current loss = 0.016751088201999664
# | Step=6，current loss = 0.07139499485492706
# | Step=7，current loss = 0.06786869466304779
# | Step=8，current loss = 0.07059244811534882
# | Step=9，current loss = 0.010069012641906738
# | Step=10，current loss = 0.011963628232479095
# | Step=11，current loss = 0.026074759662151337
# | Step=12，current loss = 0.07782219350337982
# | Step=13，current loss = 0.09510334581136703
# | Step=14，current loss = 0.03412999212741852
# | Step=15，current loss = 0.06911817193031311
# epoch:55
# | Step=0，current loss = 0.1148933619260788
# | Step=1，current loss = 0.11228639632463455
# | Step=2，current loss = 0.09239384531974792
# | Step=3，current loss = 0.06005024537444115
# | Step=4，current loss = 0.10925356298685074
# | Step=5，current loss = 0.040893323719501495
# | Step=6，current loss = 0.05476032942533493
# | Step=7，current loss = 0.035646162927150726
# | Step=8，current loss = 0.02902858890593052
# | Step=9，current loss = 0.07019416242837906
# | Step=10，current loss = 0.05856452137231827
# | Step=11，current loss = 0.17678460478782654
# | Step=12，current loss = 0.045226480811834335
# | Step=13，current loss = 0.2549743056297302
# | Step=14，current loss = 0.04925680160522461
# | Step=15，current loss = 0.030937593430280685
# epoch:56
# | Step=0，current loss = 0.09384502470493317
# | Step=1，current loss = 0.17113152146339417
# | Step=2，current loss = 0.041807591915130615
# | Step=3，current loss = 0.0867040753364563
# | Step=4，current loss = 0.040247976779937744
# | Step=5，current loss = 0.019853688776493073
# | Step=6，current loss = 0.0270615816116333
# | Step=7，current loss = 0.007400572299957275
# | Step=8，current loss = 0.019068177789449692
# | Step=9，current loss = 0.044150639325380325
# | Step=10，current loss = 0.11855244636535645
# | Step=11，current loss = 0.03364391624927521
# | Step=12，current loss = 0.032938696444034576
# | Step=13，current loss = 0.03252113610506058
# | Step=14，current loss = 0.09187445789575577
# | Step=15，current loss = 0.030886761844158173
# epoch:57
# | Step=0，current loss = 0.014135807752609253
# | Step=1，current loss = 0.08471328765153885
# | Step=2，current loss = 0.10009563714265823
# | Step=3，current loss = 0.03370226174592972
# | Step=4，current loss = 0.1438010036945343
# | Step=5，current loss = 0.1369398534297943
# | Step=6，current loss = 0.032194964587688446
# | Step=7，current loss = 0.044048890471458435
# | Step=8，current loss = 0.09886538982391357
# | Step=9，current loss = 0.2269814908504486
# | Step=10，current loss = 0.2336047738790512
# | Step=11，current loss = 0.2723073959350586
# | Step=12，current loss = 0.01874660700559616
# | Step=13，current loss = 0.07902617752552032
# | Step=14，current loss = 0.13640852272510529
# | Step=15，current loss = 0.06770861148834229
# epoch:58
# | Step=0，current loss = 0.053780242800712585
# | Step=1，current loss = 0.03377368301153183
# | Step=2，current loss = 0.07568003237247467
# | Step=3，current loss = 0.10845346003770828
# | Step=4，current loss = 0.14091545343399048
# | Step=5，current loss = 0.047573015093803406
# | Step=6，current loss = 0.24472317099571228
# | Step=7，current loss = 0.016127727925777435
# | Step=8，current loss = 0.031233981251716614
# | Step=9，current loss = 0.15248413383960724
# | Step=10，current loss = 0.10579472780227661
# | Step=11，current loss = 0.09467155486345291
# | Step=12，current loss = 0.1013522744178772
# | Step=13，current loss = 0.10378936678171158
# | Step=14，current loss = 0.023215338587760925
# | Step=15，current loss = 0.12148119509220123
# epoch:59
# | Step=0，current loss = 0.07993384450674057
# | Step=1，current loss = 0.08315439522266388
# | Step=2，current loss = 0.14397981762886047
# | Step=3，current loss = 0.19065327942371368
# | Step=4，current loss = 0.07840464264154434
# | Step=5，current loss = 0.15819963812828064
# | Step=6，current loss = 0.3791605830192566
# | Step=7，current loss = 0.016840606927871704
# | Step=8，current loss = 0.052436914294958115
# | Step=9，current loss = 0.05616874620318413
# | Step=10，current loss = 0.019123617559671402
# | Step=11，current loss = 0.10247042775154114
# | Step=12，current loss = 0.06302100419998169
# | Step=13，current loss = 0.08707907795906067
# | Step=14，current loss = 0.01964927464723587
# | Step=15，current loss = 0.022500023245811462
# epoch:60
# | Step=0，current loss = 0.045696940273046494
# | Step=1，current loss = 0.12361554056406021
# | Step=2，current loss = 0.06320758908987045
# | Step=3，current loss = 0.0730210542678833
# | Step=4，current loss = 0.1130601093173027
# | Step=5，current loss = 0.0181356742978096
# | Step=6，current loss = 0.14221617579460144
# | Step=7，current loss = 0.08470765501260757
# | Step=8，current loss = 0.015638329088687897
# | Step=9，current loss = 0.11052121967077255
# | Step=10，current loss = 0.05329896882176399
# | Step=11，current loss = 0.05324961617588997
# | Step=12，current loss = 0.059089772403240204
# | Step=13，current loss = 0.042039308696985245
# | Step=14，current loss = 0.008959397673606873
# | Step=15，current loss = 0.24798357486724854
# epoch:61
# | Step=0，current loss = 0.0726645365357399
# | Step=1，current loss = 0.16569912433624268
# | Step=2，current loss = 0.03252636641263962
# | Step=3，current loss = 0.09556355327367783
# | Step=4，current loss = 0.08585741370916367
# | Step=5，current loss = 0.09633965790271759
# | Step=6，current loss = 0.09993422031402588
# | Step=7，current loss = 0.1408614069223404
# | Step=8，current loss = 0.013205818831920624
# | Step=9，current loss = 0.08325063437223434
# | Step=10，current loss = 0.07276402413845062
# | Step=11，current loss = 0.048905033618211746
# | Step=12，current loss = 0.035001493990421295
# | Step=13，current loss = 0.017282746732234955
# | Step=14，current loss = 0.24012446403503418
# | Step=15，current loss = 0.17349034547805786
# epoch:62
# | Step=0，current loss = 0.00875350832939148
# | Step=1，current loss = 0.19660599529743195
# | Step=2，current loss = 0.17298544943332672
# | Step=3，current loss = 0.07745517045259476
# | Step=4，current loss = 0.06576260924339294
# | Step=5，current loss = 0.1715800017118454
# | Step=6，current loss = 0.0460275299847126
# | Step=7，current loss = 0.0320805162191391
# | Step=8，current loss = 0.08163739740848541
# | Step=9，current loss = 0.023041464388370514
# | Step=10，current loss = 0.1301053911447525
# | Step=11，current loss = 0.04398858919739723
# | Step=12，current loss = 0.17949937283992767
# | Step=13，current loss = 0.05881797894835472
# | Step=14，current loss = 0.03565660119056702
# | Step=15，current loss = 0.02661147713661194
# epoch:63
# | Step=0，current loss = 0.012425489723682404
# | Step=1，current loss = 0.04292142018675804
# | Step=2，current loss = 0.044337738305330276
# | Step=3，current loss = 0.13919934630393982
# | Step=4，current loss = 0.21774302423000336
# | Step=5，current loss = 0.10122330486774445
# | Step=6，current loss = 0.06383774429559708
# | Step=7，current loss = 0.13055293262004852
# | Step=8，current loss = 0.11641664803028107
# | Step=9，current loss = 0.23580355942249298
# | Step=10，current loss = 0.3034425377845764
# | Step=11，current loss = 0.287838876247406
# | Step=12，current loss = 0.014620974659919739
# | Step=13，current loss = 0.23014551401138306
# | Step=14，current loss = 0.17688053846359253
# | Step=15，current loss = 0.0465984120965004
# epoch:64
# | Step=0，current loss = 0.04486771300435066
# | Step=1，current loss = 0.06176934391260147
# | Step=2，current loss = 0.2351018488407135
# | Step=3，current loss = 0.18887419998645782
# | Step=4，current loss = 0.021761491894721985
# | Step=5，current loss = 0.028451211750507355
# | Step=6，current loss = 0.026412703096866608
# | Step=7，current loss = 0.061897989362478256
# | Step=8，current loss = 0.12157892435789108
# | Step=9，current loss = 0.5299826860427856
# | Step=10，current loss = 0.017498232424259186
# | Step=11，current loss = 0.2161497324705124
# | Step=12，current loss = 0.024941034615039825
# | Step=13，current loss = 0.1871454417705536
# | Step=14，current loss = 0.09025074541568756
# | Step=15，current loss = 0.01364542543888092
# epoch:65
# | Step=0，current loss = 0.04261740297079086
# | Step=1，current loss = 0.007957354187965393
# | Step=2，current loss = 0.05632723122835159
# | Step=3，current loss = 0.19688239693641663
# | Step=4，current loss = 0.06091466546058655
# | Step=5，current loss = 0.014544524252414703
# | Step=6，current loss = 0.09389549493789673
# | Step=7，current loss = 0.028663698583841324
# | Step=8，current loss = 0.008480094373226166
# | Step=9，current loss = 0.14690138399600983
# | Step=10，current loss = 0.029597237706184387
# | Step=11，current loss = 0.019263744354248047
# | Step=12，current loss = 0.020616307854652405
# | Step=13，current loss = 0.013551682233810425
# | Step=14，current loss = 0.03533560782670975
# | Step=15，current loss = 0.06272915750741959
# epoch:66
# | Step=0，current loss = 0.043995052576065063
# | Step=1，current loss = 0.017238564789295197
# | Step=2，current loss = 0.10936933755874634
# | Step=3，current loss = 0.03149087727069855
# | Step=4，current loss = 0.0497245192527771
# | Step=5，current loss = 0.06930327415466309
# | Step=6，current loss = 0.055472519248723984
# | Step=7，current loss = 0.14084592461585999
# | Step=8，current loss = 0.044860221445560455
# | Step=9，current loss = 0.08494294434785843
# | Step=10，current loss = 0.11104202270507812
# | Step=11，current loss = 0.031108304858207703
# | Step=12，current loss = 0.247480571269989
# | Step=13，current loss = 0.033841513097286224
# | Step=14，current loss = 0.3709608316421509
# | Step=15，current loss = 0.04773448407649994
# epoch:67
# | Step=0，current loss = 0.10242690145969391
# | Step=1，current loss = 0.04832538217306137
# | Step=2，current loss = 0.17206154763698578
# | Step=3，current loss = 0.019788287580013275
# | Step=4，current loss = 0.10048004984855652
# | Step=5，current loss = 0.17239990830421448
# | Step=6，current loss = 0.03110787272453308
# | Step=7，current loss = 0.139069065451622
# | Step=8，current loss = 0.08615342527627945
# | Step=9，current loss = 0.024521227926015854
# | Step=10，current loss = 0.009578488767147064
# | Step=11，current loss = 0.014944501221179962
# | Step=12，current loss = 0.07155577838420868
# | Step=13，current loss = 0.13788039982318878
# | Step=14，current loss = 0.020399417728185654
# | Step=15，current loss = 0.01963358372449875
# ...
# | Step=0，current loss = 0.06601279973983765
# | Step=1，current loss = 0.08428645879030228
# | Step=2，current loss = 0.03781314194202423
# | Step=3，current loss = 0.05523483455181122
# | Step=4，current loss = 0.011942081153392792
# | Step=5，current loss = 0.06383699178695679
# | Step=6，current loss = 0.02058251202106476
# | Step=7，current loss = 0.004135191440582275
# | Step=8，current loss = 0.0304827019572258
# | Step=9，current loss = 0.13104943931102753
# | Step=10，current loss = 0.009234696626663208
# | Step=11，current loss = 0.02558322250843048
# | Step=12，current loss = 0.09295321255922318
# | Step=13，current loss = 0.04785900563001633
# | Step=14，current loss = 0.002083331346511841
# | Step=15，current loss = 0.006320178508758545
# epoch:160
# | Step=0，current loss = 0.00572676956653595
# | Step=1，current loss = 0.023395434021949768
# | Step=2，current loss = 0.15400895476341248
# | Step=3，current loss = 0.007152296602725983
# | Step=4，current loss = 0.021288350224494934
# | Step=5，current loss = 0.049509935081005096
# | Step=6，current loss = 0.002097412943840027
# | Step=7，current loss = 0.02060190588235855
# | Step=8，current loss = 0.012673884630203247
# | Step=9，current loss = 0.026714995503425598
# | Step=10，current loss = 0.1137443408370018
# | Step=11，current loss = 0.07631082832813263
# | Step=12，current loss = 0.01812814176082611
# | Step=13，current loss = 0.15208469331264496
# | Step=14，current loss = 0.09444506466388702
# | Step=15，current loss = 0.029000580310821533
# epoch:161
# | Step=0，current loss = 0.05552266538143158
# | Step=1，current loss = 0.09091965854167938
# | Step=2，current loss = 0.05262453854084015
# | Step=3，current loss = 0.019817478954792023
# | Step=4，current loss = 0.10079027712345123
# | Step=5，current loss = 0.004494816064834595
# | Step=6，current loss = 0.05266080051660538
# | Step=7，current loss = 0.010399855673313141
# | Step=8，current loss = 0.061382684856653214
# | Step=9，current loss = 0.04621144384145737
# | Step=10，current loss = 0.14705970883369446
# | Step=11，current loss = 0.21443015336990356
# | Step=12，current loss = 0.010593228042125702
# | Step=13，current loss = 0.048757340759038925
# | Step=14，current loss = 0.0014934241771697998
# | Step=15，current loss = 0.08499062061309814
# epoch:162
# | Step=0，current loss = 0.006687819957733154
# | Step=1，current loss = 0.01911064237356186
# | Step=2，current loss = 0.03603159636259079
# | Step=3，current loss = 0.08118047565221786
# | Step=4，current loss = 0.033933643251657486
# | Step=5，current loss = 0.003442719578742981
# | Step=6，current loss = 0.04711643606424332
# | Step=7，current loss = 0.028914861381053925
# | Step=8，current loss = 0.06822793185710907
# | Step=9，current loss = 0.08648902922868729
# | Step=10，current loss = 0.012895546853542328
# | Step=11，current loss = 0.06292490661144257
# | Step=12，current loss = 0.006762996315956116
# | Step=13，current loss = 0.13009041547775269
# | Step=14，current loss = 0.08845145255327225
# | Step=15，current loss = 0.17523729801177979
# epoch:163
# | Step=0，current loss = 0.034442588686943054
# | Step=1，current loss = 0.03361067175865173
# | Step=2，current loss = 0.044743698090314865
# | Step=3，current loss = 0.1032809168100357
# | Step=4，current loss = 0.025303445756435394
# | Step=5，current loss = 0.016307219862937927
# | Step=6，current loss = 0.032587192952632904
# | Step=7，current loss = 0.014980919659137726
# | Step=8，current loss = 0.12406735867261887
# | Step=9，current loss = 0.014956094324588776
# | Step=10，current loss = 0.03674139082431793
# | Step=11，current loss = 0.004496976733207703
# | Step=12，current loss = 0.08887024223804474
# | Step=13，current loss = 0.012231417000293732
# | Step=14，current loss = 0.30469954013824463
# | Step=15，current loss = 0.24318110942840576
# epoch:164
# | Step=0，current loss = 0.004751816391944885
# | Step=1，current loss = 0.0026389211416244507
# | Step=2，current loss = 0.007884077727794647
# | Step=3，current loss = 0.0023998022079467773
# | Step=4，current loss = 0.14006997644901276
# | Step=5，current loss = 0.024613186717033386
# | Step=6，current loss = 0.010661952197551727
# | Step=7，current loss = 0.05331262946128845
# | Step=8，current loss = 0.02077440172433853
# | Step=9，current loss = 0.08664055168628693
# | Step=10，current loss = 0.0420224629342556
# | Step=11，current loss = 0.023620791733264923
# | Step=12，current loss = 0.07226812094449997
# | Step=13，current loss = 0.03648635372519493
# | Step=14，current loss = 0.13867886364459991
# | Step=15，current loss = 0.005928486585617065
# epoch:165
# | Step=0，current loss = 0.0073678940534591675
# | Step=1，current loss = 0.018145933747291565
# | Step=2，current loss = 0.008434399962425232
# | Step=3，current loss = 0.14477436244487762
# | Step=4，current loss = 0.017361782491207123
# | Step=5，current loss = 0.012599378824234009
# | Step=6，current loss = 0.04490544646978378
# | Step=7，current loss = 0.14843133091926575
# | Step=8，current loss = 0.019663967192173004
# | Step=9，current loss = 0.010003887116909027
# | Step=10，current loss = 0.00722908228635788
# | Step=11，current loss = 0.11239296942949295
# | Step=12，current loss = 0.04879644140601158
# | Step=13，current loss = 0.13458651304244995
# | Step=14，current loss = 0.006887868046760559
# | Step=15，current loss = 0.034440476447343826
# epoch:166
# | Step=0，current loss = 0.06811733543872833
# | Step=1，current loss = 0.06823652237653732
# | Step=2，current loss = 0.056077342480421066
# | Step=3，current loss = 0.012383759021759033
# | Step=4，current loss = 0.04951486736536026
# | Step=5，current loss = 0.04099389910697937
# | Step=6，current loss = 0.13453121483325958
# | Step=7，current loss = 0.029050417244434357
# | Step=8，current loss = 0.024806417524814606
# | Step=9，current loss = 0.010953933000564575
# | Step=10，current loss = 0.0433613657951355
# | Step=11，current loss = 0.008782587945461273
# | Step=12，current loss = 0.012733891606330872
# | Step=13，current loss = 0.0480562224984169
# | Step=14，current loss = 0.013079270720481873
# | Step=15，current loss = 0.01745188981294632
# epoch:167
# | Step=0，current loss = 0.06552338600158691
# | Step=1，current loss = 0.006742797791957855
# | Step=2，current loss = 0.04077760875225067
# | Step=3，current loss = 0.11979860067367554
# | Step=4，current loss = 0.01847582310438156
# | Step=5，current loss = 0.03662946820259094
# | Step=6，current loss = 0.25180119276046753
# | Step=7，current loss = 0.1934792399406433
# | Step=8，current loss = 0.012349829077720642
# | Step=9，current loss = 0.06546634435653687
# | Step=10，current loss = 0.030414864420890808
# | Step=11，current loss = 0.17576517164707184
# | Step=12，current loss = 0.013528555631637573
# | Step=13，current loss = 0.01519300788640976
# | Step=14，current loss = 0.017696328461170197
# | Step=15，current loss = 0.018086053431034088
# epoch:168
# | Step=0，current loss = 0.008243635296821594
# | Step=1，current loss = 0.06646895408630371
# | Step=2，current loss = 0.24749626219272614
# | Step=3，current loss = 0.042926132678985596
# | Step=4，current loss = 0.19659322500228882
# | Step=5，current loss = 0.010425262153148651
# | Step=6，current loss = 0.03840125352144241
# | Step=7，current loss = 0.07077701389789581
# | Step=8，current loss = 0.23020610213279724
# | Step=9，current loss = 0.01465674489736557
# | Step=10，current loss = 0.0660615935921669
# | Step=11，current loss = 0.13276861608028412
# | Step=12，current loss = 0.004447042942047119
# | Step=13，current loss = 0.013081550598144531
# | Step=14，current loss = 0.008935227990150452
# | Step=15，current loss = 0.29839468002319336
# epoch:169
# | Step=0，current loss = 0.13939304649829865
# | Step=1，current loss = 0.06333862990140915
# | Step=2，current loss = 0.06381566822528839
# | Step=3，current loss = 0.11858657747507095
# | Step=4，current loss = 0.052344322204589844
# | Step=5，current loss = 0.005711197853088379
# | Step=6，current loss = 0.06650654971599579
# | Step=7，current loss = 0.019767411053180695
# | Step=8，current loss = 0.15238888561725616
# | Step=9，current loss = 0.013787604868412018
# | Step=10，current loss = 0.004355266690254211
# | Step=11，current loss = 0.024522170424461365
# | Step=12，current loss = 0.027520164847373962
# | Step=13，current loss = 0.0022753775119781494
# | Step=14，current loss = 0.011666692793369293
# | Step=15，current loss = 0.06371496617794037
# epoch:170
# | Step=0，current loss = 0.060946524143218994
# | Step=1，current loss = 0.00924760103225708
# | Step=2，current loss = 0.018490858376026154
# | Step=3，current loss = 0.007881343364715576
# | Step=4，current loss = 0.124363474547863
# | Step=5，current loss = 0.21242767572402954
# | Step=6，current loss = 0.08633340150117874
# | Step=7，current loss = 0.044202812016010284
# | Step=8，current loss = 0.004862666130065918
# | Step=9，current loss = 0.01907021552324295
# | Step=10，current loss = 0.3465530276298523
# | Step=11，current loss = 0.006898358464241028
# | Step=12，current loss = 0.011576719582080841
# | Step=13，current loss = 0.05169215798377991
# | Step=14，current loss = 0.03020249307155609
# | Step=15，current loss = 0.002851933240890503
# epoch:171
# | Step=0，current loss = 0.003667019307613373
# | Step=1，current loss = 0.018734022974967957
# | Step=2，current loss = 0.1506086140871048
# | Step=3，current loss = 0.02773316204547882
# | Step=4，current loss = 0.006728112697601318
# | Step=5，current loss = 0.014733023941516876
# | Step=6，current loss = 0.010830283164978027
# | Step=7，current loss = 0.007885918021202087
# | Step=8，current loss = 0.023391306400299072
# | Step=9，current loss = 0.007140100002288818
# | Step=10，current loss = 0.030142463743686676
# | Step=11，current loss = 0.042209282517433167
# | Step=12，current loss = 0.007115401327610016
# | Step=13，current loss = 0.06103193759918213
# | Step=14，current loss = 0.02332540601491928
# | Step=15，current loss = 0.013113193213939667
# epoch:172
# | Step=0，current loss = 0.2214812934398651
# | Step=1，current loss = 0.017321716994047165
# | Step=2，current loss = 0.054582685232162476
# | Step=3，current loss = 0.0036015957593917847
# | Step=4，current loss = 0.06788008660078049
# | Step=5，current loss = 0.0099550262093544
# | Step=6，current loss = 0.16833636164665222
# | Step=7，current loss = 0.05508612096309662
# | Step=8，current loss = 0.04304494336247444
# | Step=9，current loss = 0.009883016347885132
# | Step=10，current loss = 0.0885586068034172
# | Step=11，current loss = 0.07551674544811249
# | Step=12，current loss = 0.12077060341835022
# | Step=13，current loss = 0.01342008262872696
# | Step=14，current loss = 0.009947061538696289
# | Step=15，current loss = 0.027902744710445404
# epoch:173
# | Step=0，current loss = 0.008564375340938568
# | Step=1，current loss = 0.07651593536138535
# | Step=2，current loss = 0.07182715833187103
# | Step=3，current loss = 0.014509230852127075
# | Step=4，current loss = 0.01255682110786438
# | Step=5，current loss = 0.003602549433708191
# | Step=6，current loss = 0.2479429841041565
# | Step=7，current loss = 0.06720191240310669
# | Step=8，current loss = 0.007698729634284973
# | Step=9，current loss = 0.08014792948961258
# | Step=10，current loss = 0.01829143613576889
# | Step=11，current loss = 0.06556328386068344
# | Step=12，current loss = 0.01832987368106842
# | Step=13，current loss = 0.09701519459486008
# | Step=14，current loss = 0.02417643740773201
# | Step=15，current loss = 0.09167534857988358
# epoch:174
# | Step=0，current loss = 0.005114346742630005
# | Step=1，current loss = 0.013164035975933075
# | Step=2，current loss = 0.007582932710647583
# | Step=3，current loss = 0.12213130295276642
# | Step=4，current loss = 0.01313202828168869
# | Step=5，current loss = 0.009194143116474152
# | Step=6，current loss = 0.006939038634300232
# | Step=7，current loss = 0.0819445252418518
# | Step=8，current loss = 0.030451424419879913
# | Step=9，current loss = 0.05408629775047302
# | Step=10，current loss = 0.001567840576171875
# | Step=11，current loss = 0.014603428542613983
# | Step=12，current loss = 0.08048780262470245
# | Step=13，current loss = 0.16781024634838104
# | Step=14，current loss = 0.14541932940483093
# | Step=15，current loss = 0.03778691589832306
# epoch:175
# | Step=0，current loss = 0.02196773886680603
# | Step=1，current loss = 0.0038499385118484497
# | Step=2，current loss = 0.3723493814468384
# | Step=3，current loss = 0.28498029708862305
# | Step=4，current loss = 0.006690159440040588
# | Step=5，current loss = 0.012184053659439087
# | Step=6，current loss = 0.009149372577667236
# | Step=7，current loss = 0.11948058754205704
# | Step=8，current loss = 0.032458484172821045
# | Step=9，current loss = 0.02641923353075981
# | Step=10，current loss = 0.06495371460914612
# | Step=11，current loss = 0.008515439927577972
# | Step=12，current loss = 0.0758051723241806
# | Step=13，current loss = 0.01003938913345337
# | Step=14，current loss = 0.030624739825725555
# | Step=15，current loss = 0.06443378329277039
# epoch:176
# | Step=0，current loss = 0.004709213972091675
# | Step=1，current loss = 0.013280652463436127
# | Step=2，current loss = 0.035604774951934814
# | Step=3，current loss = 0.0817902684211731
# | Step=4，current loss = 0.004361249506473541
# | Step=5，current loss = 0.03303112834692001
# | Step=6，current loss = 0.1000639870762825
# | Step=7，current loss = 0.003936022520065308
# | Step=8，current loss = 0.08828586339950562
# | Step=9，current loss = 0.24405018985271454
# | Step=10，current loss = 0.013714566826820374
# | Step=11，current loss = 0.01355096697807312
# | Step=12，current loss = 0.06093970686197281
# | Step=13，current loss = 0.03252047300338745
# | Step=14，current loss = 0.16080573201179504
# | Step=15，current loss = 0.05013108253479004
# epoch:177
# | Step=0，current loss = 0.02334238588809967
# | Step=1，current loss = 0.028410963714122772
# | Step=2，current loss = 0.03291885182261467
# | Step=3，current loss = 0.010286405682563782
# | Step=4，current loss = 0.01278723031282425
# | Step=5，current loss = 0.032115638256073
# | Step=6，current loss = 0.008808739483356476
# | Step=7，current loss = 0.10134382545948029
# | Step=8，current loss = 0.0459568165242672
# | Step=9，current loss = 0.03137780725955963
# | Step=10，current loss = 0.004041314125061035
# | Step=11，current loss = 0.06585115194320679
# | Step=12，current loss = 0.04068353772163391
# | Step=13，current loss = 0.027429841458797455
# | Step=14，current loss = 0.011900313198566437
# | Step=15，current loss = 0.21295112371444702
# epoch:178
# | Step=0，current loss = 0.029077991843223572
# | Step=1，current loss = 0.03380490839481354
# | Step=2，current loss = 0.12449057400226593
# | Step=3，current loss = 0.023657821118831635
# | Step=4，current loss = 0.01941177248954773
# | Step=5，current loss = 0.025102298706769943
# | Step=6，current loss = 0.06598570197820663
# | Step=7，current loss = 0.007484324276447296
# | Step=8，current loss = 0.02546641230583191
# | Step=9，current loss = 0.020109429955482483
# | Step=10，current loss = 0.020446546375751495
# | Step=11，current loss = 0.016718663275241852
# | Step=12，current loss = 0.014959089457988739
# | Step=13，current loss = 0.009229622781276703
# | Step=14，current loss = 0.00567936897277832
# | Step=15，current loss = 0.013481028378009796
# epoch:179
# | Step=0，current loss = 0.035194031894207
# | Step=1，current loss = 0.02703264355659485
# | Step=2，current loss = 0.0990196019411087
# | Step=3，current loss = 0.04955519363284111
# | Step=4，current loss = 0.1988147348165512
# | Step=5，current loss = 0.26290982961654663
# | Step=6，current loss = 0.08762724697589874
# | Step=7，current loss = 0.048833273351192474
# | Step=8，current loss = 0.16511470079421997
# | Step=9，current loss = 0.023836538195610046
# | Step=10，current loss = 0.05040544271469116
# | Step=11，current loss = 0.07433278113603592
# | Step=12，current loss = 0.015295706689357758
# | Step=13，current loss = 0.20395977795124054
# | Step=14，current loss = 0.035613566637039185
# | Step=15，current loss = 0.16834977269172668
# epoch:180
# | Step=0，current loss = 0.031088057905435562
# | Step=1，current loss = 0.03869347274303436
# | Step=2，current loss = 0.09629283845424652
# | Step=3，current loss = 0.026030585169792175
# | Step=4，current loss = 0.03411344438791275
# | Step=5，current loss = 0.03869113326072693
# | Step=6，current loss = 0.1791350096464157
# | Step=7，current loss = 0.016295254230499268
# | Step=8，current loss = 0.036655060946941376
# | Step=9，current loss = 0.08576343953609467
# | Step=10，current loss = 0.016323640942573547
# | Step=11，current loss = 0.03721117228269577
# | Step=12，current loss = 0.01833295077085495
# | Step=13，current loss = 0.007663622498512268
# | Step=14，current loss = 0.009959660470485687
# | Step=15，current loss = 0.05206858366727829
# accuracy:92.43000030517578
